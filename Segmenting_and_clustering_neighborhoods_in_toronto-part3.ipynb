# %% [markdown]
# # Segmenting and Clustering Neighborhoods in Toronto

# %% [markdown]
# Let's download all the libraries that will be used for the clustring:

# %%
# data scraping and handling JSON files
from bs4 import BeautifulSoup
import requests
import json
from pandas.io.json import json_normalize

# handling data
import numpy as np
import pandas as pd

# visualization
import matplotlib.pyplot as plt
# %matplotlib inline
import folium

# clustering
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## __PART 1__: Scraping Wikipedia page to produce the neighborhoods table.

# %% [markdown]
# We proceed with scraping the Wikipedia page in order to obtain the information about neighborhoods in Toronto:
# - first, we get the data from the web page and extract the part that contains the table,
# - second, we clean the data and store it in three lists, corresponding to postcode, borough and neighborhood,
# - lastly, we create a pandas dataframe to hold the table and perform the modifications, suggested in the assignment (drop the cells with 'Not assigned' borough, combine the rows with the same code area, modify 'Not assigned' neighborhoods).

# %%
# get the content of the Wikipedia page
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
page = requests.get(url)

# Parse the content with BeautifulSoup
soup = BeautifulSoup(page.content, 'html.parser')
values = soup.find( "table" ) 
table = values.findAll('td')
table[0:15]
# Out:
# [<td>M1A</td>, <td>Not assigned</td>, <td>Not assigned
#  </td>, <td>M2A</td>, <td>Not assigned</td>, <td>Not assigned
#  </td>, <td>M3A</td>, <td><a href="/wiki/North_York" title="North York">North York</a></td>, <td><a href="/wiki/Parkwoods" title="Parkwoods">Parkwoods</a>
#  </td>, <td>M4A</td>, <td><a href="/wiki/North_York" title="North York">North York</a></td>, <td><a href="/wiki/Victoria_Village" title="Victoria Village">Victoria Village</a>
#  </td>, <td>M5A</td>, <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>, <td><a href="/wiki/Harbourfront_(Toronto)" title="Harbourfront (Toronto)">Harbourfront</a>
#  </td>]

# %%
# Clean the data and store the columns in three lists
postcode = []
borough = []
neighborhood = []
for i, value in enumerate(table):
    value = str(value).strip('<td>').strip('/<')
    value = value.split('title="')[-1].split('">')[0]
    value = value.split('\n')[0].split(' (')[0]
    value = value.split(', Toronto')[0]
    
    if (i+1)%3 == 1:
        postcode.append(value)
    elif (i+1)%3 == 2:
        borough.append(value)
    else:
        neighborhood.append(value)
        
print("Postcode : ", postcode[0:5])
print("Borough : ", borough[0:5])
print("Neighborhood : ", neighborhood[0:5])
# Out:
# Postcode :  ['M1A', 'M2A', 'M3A', 'M4A', 'M5A']
# Borough :  ['Not assigned', 'Not assigned', 'North York', 'North York', 'Downtown Toronto']
# Neighborhood :  ['Not assigned', 'Not assigned', 'Parkwoods', 'Victoria Village', 'Harbourfront']

# %%
# Store the data in a pandas dataframe
df = pd.DataFrame({'Postcode' : postcode,
                  'Borough'  : borough,
                  'Neighborhood' : neighborhood})
df.head(10)
# Out:
#   Postcode           Borough      Neighborhood
# 0      M1A      Not assigned      Not assigned
# 1      M2A      Not assigned      Not assigned
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront
# 5      M5A  Downtown Toronto       Regent Park
# 6      M6A        North York  Lawrence Heights
# 7      M6A        North York    Lawrence Manor
# 8      M7A      Queen's Park      Not assigned
# 9      M8A      Not assigned      Not assigned

# %%
# Drop cells wiht borough = 'Not assigned'
df = df[df['Borough'] != 'Not assigned']
df.head(10)
# Out:
#    Postcode           Borough      Neighborhood
# 2       M3A        North York         Parkwoods
# 3       M4A        North York  Victoria Village
# 4       M5A  Downtown Toronto      Harbourfront
# 5       M5A  Downtown Toronto       Regent Park
# 6       M6A        North York  Lawrence Heights
# 7       M6A        North York    Lawrence Manor
# 8       M7A      Queen's Park      Not assigned
# 10      M9A         Etobicoke  Islington Avenue
# 11      M1B       Scarborough             Rouge
# 12      M1B       Scarborough           Malvern

# %%
# Combine rows with same postcode  
def f(x):
    return pd.Series(dict(Borough = x['Borough'].unique()[0], 
                        Neighborhood = ', '.join(x['Neighborhood'])))
df = df.groupby('Postcode').apply(f)
df.reset_index(inplace=True)
df.head(10)
# Out:
#   Postcode      Borough                                     Neighborhood
# 0      M1B  Scarborough                                   Rouge, Malvern
# 1      M1C  Scarborough           Highland Creek, Rouge Hill, Port Union
# 2      M1E  Scarborough                Guildwood, Morningside, West Hill
# 3      M1G  Scarborough                                           Woburn
# 4      M1H  Scarborough                                        Cedarbrae
# 5      M1J  Scarborough                              Scarborough Village
# 6      M1K  Scarborough      East Birchmount Park, Ionview, Kennedy Park
# 7      M1L  Scarborough                  Clairlea, Golden Mile, Oakridge
# 8      M1M  Scarborough  Cliffcrest, Cliffside, Scarborough Village West
# 9      M1N  Scarborough                      Birch Cliff, Cliffside West

# %%
# Transform cell with 'Not assigned' Neighborhood
df.loc[df['Neighborhood'] == 'Not assigned','Neighborhood']  = df.loc[df['Neighborhood'] == 'Not assigned','Borough']

# %% [markdown]
# We print the shape of the resulting dataframe and also double-check the following:
# - number of unique postcodes coincides with the number of rows in the dataframe
# - there are no 'Not assigned' values in either 'Borough' or 'Neighborhood' columns

# %%
# Check that all postcodes are unique 
# and there are no 'Not assigned' values

print("Shape of the dataframe is ", df.shape)
print("There are {} unique postcodes".format(df['Postcode'].count()))
print("Are there any 'Not assigned' boroughs? : ", 
      df['Borough'].isin(['Not assigned']).any())
print("Are there any 'Not assigned' neighborhoods? : ", 
      df['Neighborhood'].isin(['Not assigned']).any())
# Out:
# Shape of the dataframe is  (103, 3)
# There are 103 unique postcodes
# Are there any 'Not assigned' boroughs? :  False
# Are there any 'Not assigned' neighborhoods? :  False

# %% [markdown]
# ## __PART 2__: Getting geographical coordinates of the neighborhoods.

# %% [markdown]
# I tried to use geocoder, as it was suggested, but it didn't work: after waiting for > 10 minutes to get the coordinates, I gave up and decided to use the .csv file.

# %%
# download coordinates
coordinates = pd.read_csv('http://cocl.us/Geospatial_data')
coordinates.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
# insert 'Latitude' and 'Longitude' columns into the dataframe
df['Latitude'] = coordinates['Latitude']
df['Longitude'] = coordinates['Longitude']
df.head()
# Out:
#   Postcode      Borough                            Neighborhood   Latitude  \
# 0      M1B  Scarborough                          Rouge, Malvern  43.806686
# 1      M1C  Scarborough  Highland Creek, Rouge Hill, Port Union  43.784535
# 2      M1E  Scarborough       Guildwood, Morningside, West Hill  43.763573
# 3      M1G  Scarborough                                  Woburn  43.770992
# 4      M1H  Scarborough                               Cedarbrae  43.773136
#
#    Longitude
# 0 -79.194353
# 1 -79.160497
# 2 -79.188711
# 3 -79.216917
# 4 -79.239476

# %% [markdown]
# ## __PART 3__: Explore and cluster the neighborhoods.

# %% [markdown]
# We start by examining our final data.

# %%
print("There are {} unique boroughs".format(len(df['Borough'].unique())))
print("There are {} unique neighborhoods".format(
    len(df['Neighborhood'].unique())))
# Out:
# There are 11 unique boroughs
# There are 103 unique neighborhoods

# %% [markdown]
# Let's also visualize the neighborhoods.

# %%
# !conda install -c conda-forge geopy --yes
from geopy.geocoders import Nominatim
address = 'Toronto, Canada'

geolocator = Nominatim(user_agent="tor_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(df['Latitude'], df['Longitude'], df['Borough'], df['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# Collecting package metadata: done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.6.13
#   latest version: 4.6.14
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# # All requested packages already installed.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### 1. Let's also explore one neighborhood, using Foursquare data.
#
# Following the approach from the Lab, let pick a neighborhood and see what kind of venues are popular in it.
#
# __NOTE__: I cut the cell, containing my Client ID and Client Secret, but it should follow the current cell in order for the code to work.

# %%
neighborhood = 'St. James Town'
neighborhood_latitude = df.loc[df['Neighborhood'] == neighborhood, 'Latitude']
neighborhood_latitude = neighborhood_latitude.values[0]
neighborhood_longitude = df.loc[df['Neighborhood'] == neighborhood, 'Longitude']
neighborhood_longitude = neighborhood_longitude.values[0]

LIMIT = 100
radius = 500
search_query = ''
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius, 
    LIMIT)

results = requests.get(url).json()

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
#                     name           categories        lat        lng
# 0  Gyu-Kaku Japanese BBQ  Japanese Restaurant  43.651422 -79.375047
# 1               Crepe TO             Creperie  43.650063 -79.374587
# 2                Terroni   Italian Restaurant  43.650927 -79.375602
# 3      GEORGE Restaurant           Restaurant  43.653346 -79.374445
# 4      Fahrenheit Coffee          Coffee Shop  43.652384 -79.372719

# %%
print('{} venues were returned by Foursquare.'.format(nearby_venues.shape[0]))
# Out:
# 100 venues were returned by Foursquare.

# %% [markdown]
# ### 2. Let's get similar data for all neighborhoods, using the function provided in the Lab

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    return(nearby_venues)

# %%
toronto_venues = getNearbyVenues(names=df['Neighborhood'],
                                   latitudes=df['Latitude'],
                                   longitudes=df['Longitude']
                                  )
# Out:
# Rouge, Malvern
# Highland Creek, Rouge Hill, Port Union
# Guildwood, Morningside, West Hill
# Woburn
# Cedarbrae
# Scarborough Village
# East Birchmount Park, Ionview, Kennedy Park
# Clairlea, Golden Mile, Oakridge
# Cliffcrest, Cliffside, Scarborough Village West
# Birch Cliff, Cliffside West
# Dorset Park, Scarborough Town Centre, Wexford Heights
# Maryvale, Wexford
# Agincourt
# Clarks Corners, Sullivan, Tam O'Shanter – Sullivan
# Agincourt North, L'Amoreaux East, Milliken, Ontario, Steeles East
# L'Amoreaux West
# Upper Rouge
# Hillcrest Village
# Fairview, Henry Farm, Oriole
# Bayview Village
# Silver Hills, York Mills
# Newtonbrook, Willowdale
# Willowdale South
# York Mills West
# Willowdale West
# Parkwoods
# Don Mills North
# Flemingdon Park, Don Mills South
# Bathurst Manor, Downsview North, Wilson Heights
# Northwood Park, York University
# CFB Toronto, Downsview East
# Downsview
# Downsview Central
# Downsview Northwest
# Victoria Village
# Woodbine Gardens, Parkview Hill
# Woodbine Heights
# The Beaches
# Leaside
# Thorncliffe Park
# East Toronto
# The Danforth West, Riverdale
# The Beaches West, India Bazaar
# Studio District
# Lawrence Park
# Davisville North
# North Toronto West
# Davisville
# Moore Park, Summerhill East
# Deer Park, Forest Hill SE, Rathnelly, South Hill, Summerhill West
# Rosedale
# Cabbagetown, St. James Town
# Church and Wellesley
# Harbourfront, Regent Park
# Ryerson, Garden District
# St. James Town
# Berczy Park
# Central Bay Street
# Adelaide, King, Richmond
# Harbourfront East, Toronto Islands, Union Station
# Design Exchange, Toronto Dominion Centre
# Commerce Court, Victoria Hotel
# Bedford Park, Lawrence Manor East
# Roselawn
# Forest Hill North, Forest Hill West
# The Annex, North Midtown, Yorkville
# Harbord, University of Toronto
# Chinatown, Grange Park, Kensington Market
# CN Tower, Bathurst Quay, Island airport, Harbourfront West, King and Spadina, Railway Lands, South Niagara
# Stn A PO Boxes 25 The Esplanade
# First Canadian Place, Underground city
# Lawrence Heights, Lawrence Manor
# Glencairn
# Humewood-Cedarvale
# Caledonia-Fairbanks
# Christie
# Dovercourt Village, Dufferin
# Little Portugal, Trinity–Bellwoods
# Brockton, Exhibition Place, Parkdale Village
# Downsview, North Park, Upwood Park
# Del Ray, Keelesdale, Mount Dennis, Silverthorn
# The Junction North, Runnymede
# High Park, The Junction South
# Parkdale, Roncesvalles
# Runnymede, Swansea
# Queen's Park
# Canada Post Gateway Processing Centre
# Business Reply Mail Processing Centre 969 Eastern
# Humber Bay Shores, Mimico South, New Toronto
# Alderwood, Long Branch
# The Kingsway, Montgomery Road, Old Mill North
# Humber Bay, King's Mill Park, Kingsway Park South East, Mimico, Old Mill, The Queensway, Fairmont Royal York Hotel, Sunnylea
# Kingsway Park South West, Mimico, The Queensway, Royal York South West, South of Bloor
# Islington Avenue
# Cloverdale, Islington, Martin Grove, Princess Gardens, West Deane Park
# Bloordale Gardens, Eringate, Markland Wood, Old Burnhamthorpe
# Humber Summit
# Emery, Humberlea
# Weston
# Westmount
# Kingsview Village, Martin Grove Gardens, Richview Gardens, St. Phillips
# Albion Gardens, Beaumond Heights, Humbergate, Mount Olive-Silverstone-Jamestown, Mount Olive-Silverstone-Jamestown, Silverstone, South Steeles, Thistletown
# Northwest

# %% [markdown]
# ### 3. There are 103 neighborhoods and to simplify analysis a lit bit, I filter out all neighborhoods for which there are less than 20 venues found.

# %%
venues_per_neighborhood = toronto_venues.groupby('Neighborhood').count()
venues_per_neighborhood.reset_index(inplace = True)
# print(venues_per_neighborhood.sort_values(by = 'Venue'))
lim = 20
more_than_20 = venues_per_neighborhood.loc[venues_per_neighborhood['Venue']>=lim,
                                           'Neighborhood']
toronto_venues = toronto_venues[toronto_venues['Neighborhood'].isin(more_than_20)]

print("Now there are {} neighborhoods to cluster".format(len(toronto_venues['Neighborhood'].unique())))
# Out:
# Now there are 31 neighborhoods to cluster

# %%
toronto_venues.groupby('Neighborhood').count()
# Out:
#                                                    Neighborhood Latitude  \
# Neighborhood
# Adelaide, King, Richmond                                             100
# Bedford Park, Lawrence Manor East                                     23
# Berczy Park                                                           57
# Cabbagetown, St. James Town                                           44
# Central Bay Street                                                    88
# Chinatown, Grange Park, Kensington Market                            100
# Church and Wellesley                                                  88
# Commerce Court, Victoria Hotel                                       100
# Davisville                                                            32
# Design Exchange, Toronto Dominion Centre                             100
# Dovercourt Village, Dufferin                                          20
# Fairview, Henry Farm, Oriole                                          66
# First Canadian Place, Underground city                               100
# Flemingdon Park, Don Mills South                                      21
# Harbord, University of Toronto                                        34
# Harbourfront East, Toronto Islands, Union Station                    100
# Harbourfront, Regent Park                                             46
# High Park, The Junction South                                         23
# Leaside                                                               33
# Little Portugal, Trinity–Bellwoods                                    63
# North Toronto West                                                    20
# Queen's Park                                                          39
# Runnymede, Swansea                                                    40
# Ryerson, Garden District                                             100
# St. James Town                                                       100
# Stn A PO Boxes 25 The Esplanade                                       95
# Studio District                                                       37
# The Annex, North Midtown, Yorkville                                   24
# The Beaches West, India Bazaar                                        22
# The Danforth West, Riverdale                                          44
# Willowdale South                                                      34
#
#                                                    Neighborhood Longitude  \
# Neighborhood
# Adelaide, King, Richmond                                              100
# Bedford Park, Lawrence Manor East                                      23
# Berczy Park                                                            57
# Cabbagetown, St. James Town                                            44
# Central Bay Street                                                     88
# Chinatown, Grange Park, Kensington Market                             100
# Church and Wellesley                                                   88
# Commerce Court, Victoria Hotel                                        100
# Davisville                                                             32
# Design Exchange, Toronto Dominion Centre                              100
# Dovercourt Village, Dufferin                                           20
# Fairview, Henry Farm, Oriole                                           66
# First Canadian Place, Underground city                                100
# Flemingdon Park, Don Mills South                                       21
# Harbord, University of Toronto                                         34
# Harbourfront East, Toronto Islands, Union Station                     100
# Harbourfront, Regent Park                                              46
# High Park, The Junction South                                          23
# Leaside                                                                33
# Little Portugal, Trinity–Bellwoods                                     63
# North Toronto West                                                     20
# Queen's Park                                                           39
# Runnymede, Swansea                                                     40
# Ryerson, Garden District                                              100
# St. James Town                                                        100
# Stn A PO Boxes 25 The Esplanade                                        95
# Studio District                                                        37
# The Annex, North Midtown, Yorkville                                    24
# The Beaches West, India Bazaar                                         22
# The Danforth West, Riverdale                                           44
# Willowdale South                                                       34
#
#                                                    Venue  Venue Latitude  \
# Neighborhood
# Adelaide, King, Richmond                             100             100
# Bedford Park, Lawrence Manor East                     23              23
# Berczy Park                                           57              57
# Cabbagetown, St. James Town                           44              44
# Central Bay Street                                    88              88
# Chinatown, Grange Park, Kensington Market            100             100
# Church and Wellesley                                  88              88
# Commerce Court, Victoria Hotel                       100             100
# Davisville                                            32              32
# Design Exchange, Toronto Dominion Centre             100             100
# Dovercourt Village, Dufferin                          20              20
# Fairview, Henry Farm, Oriole                          66              66
# First Canadian Place, Underground city               100             100
# Flemingdon Park, Don Mills South                      21              21
# Harbord, University of Toronto                        34              34
# Harbourfront East, Toronto Islands, Union Station    100             100
# Harbourfront, Regent Park                             46              46
# High Park, The Junction South                         23              23
# Leaside                                               33              33
# Little Portugal, Trinity–Bellwoods                    63              63
# North Toronto West                                    20              20
# Queen's Park                                          39              39
# Runnymede, Swansea                                    40              40
# Ryerson, Garden District                             100             100
# St. James Town                                       100             100
# Stn A PO Boxes 25 The Esplanade                       95              95
# Studio District                                       37              37
# The Annex, North Midtown, Yorkville                   24              24
# The Beaches West, India Bazaar                        22              22
# The Danforth West, Riverdale                          44              44
# Willowdale South                                      34              34
#
#                                                    Venue Longitude  \
# Neighborhood
# Adelaide, King, Richmond                                       100
# Bedford Park, Lawrence Manor East                               23
# Berczy Park                                                     57
# Cabbagetown, St. James Town                                     44
# Central Bay Street                                              88
# Chinatown, Grange Park, Kensington Market                      100
# Church and Wellesley                                            88
# Commerce Court, Victoria Hotel                                 100
# Davisville                                                      32
# Design Exchange, Toronto Dominion Centre                       100
# Dovercourt Village, Dufferin                                    20
# Fairview, Henry Farm, Oriole                                    66
# First Canadian Place, Underground city                         100
# Flemingdon Park, Don Mills South                                21
# Harbord, University of Toronto                                  34
# Harbourfront East, Toronto Islands, Union Station              100
# Harbourfront, Regent Park                                       46
# High Park, The Junction South                                   23
# Leaside                                                         33
# Little Portugal, Trinity–Bellwoods                              63
# North Toronto West                                              20
# Queen's Park                                                    39
# Runnymede, Swansea                                              40
# Ryerson, Garden District                                       100
# St. James Town                                                 100
# Stn A PO Boxes 25 The Esplanade                                 95
# Studio District                                                 37
# The Annex, North Midtown, Yorkville                             24
# The Beaches West, India Bazaar                                  22
# The Danforth West, Riverdale                                    44
# Willowdale South                                                34
#
#                                                    Venue Category
# Neighborhood
# Adelaide, King, Richmond                                      100
# Bedford Park, Lawrence Manor East                              23
# Berczy Park                                                    57
# Cabbagetown, St. James Town                                    44
# Central Bay Street                                             88
# Chinatown, Grange Park, Kensington Market                     100
# Church and Wellesley                                           88
# Commerce Court, Victoria Hotel                                100
# Davisville                                                     32
# Design Exchange, Toronto Dominion Centre                      100
# Dovercourt Village, Dufferin                                   20
# Fairview, Henry Farm, Oriole                                   66
# First Canadian Place, Underground city                        100
# Flemingdon Park, Don Mills South                               21
# Harbord, University of Toronto                                 34
# Harbourfront East, Toronto Islands, Union Station             100
# Harbourfront, Regent Park                                      46
# High Park, The Junction South                                  23
# Leaside                                                        33
# Little Portugal, Trinity–Bellwoods                             63
# North Toronto West                                             20
# Queen's Park                                                   39
# Runnymede, Swansea                                             40
# Ryerson, Garden District                                      100
# St. James Town                                                100
# Stn A PO Boxes 25 The Esplanade                                95
# Studio District                                                37
# The Annex, North Midtown, Yorkville                            24
# The Beaches West, India Bazaar                                 22
# The Danforth West, Riverdale                                   44
# Willowdale South                                               34

# %% [markdown]
# ### 4. Now we're left with one third of the initial neighborhoods. Let's proceed with encoding the venues categories and calculating frequencies.

# %%
# one hot encoding
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
categories = toronto_onehot.columns.values
toronto_onehot['Neighborhood'] = toronto_venues['Neighborhood'] 

# move neighborhood column to the first column
index = np.argwhere(categories =='Neighborhood')
categories  = list(np.delete(categories, index) )
fixed_columns = ['Neighborhood'] + categories

toronto_onehot = toronto_onehot[fixed_columns]
toronto_onehot.head()
# Out:
#                     Neighborhood  Adult Boutique  Afghan Restaurant  \
# 92  Fairview, Henry Farm, Oriole               0                  0
# 93  Fairview, Henry Farm, Oriole               0                  0
# 94  Fairview, Henry Farm, Oriole               0                  0
# 95  Fairview, Henry Farm, Oriole               0                  0
# 96  Fairview, Henry Farm, Oriole               0                  0
#
#     American Restaurant  Antique Shop  Aquarium  Argentinian Restaurant  \
# 92                    0             0         0                       0
# 93                    0             0         0                       0
# 94                    0             0         0                       0
# 95                    0             0         0                       0
# 96                    0             0         0                       0
#
#     Art Gallery  Art Museum  Arts & Crafts Store  ...  Toy / Game Store  \
# 92            0           0                    0  ...                 1
# 93            0           0                    0  ...                 0
# 94            0           0                    0  ...                 0
# 95            0           0                    0  ...                 0
# 96            0           0                    0  ...                 0
#
#     Trail  Train Station  Vegetarian / Vegan Restaurant  Video Game Store  \
# 92      0              0                              0                 0
# 93      0              0                              0                 0
# 94      0              0                              0                 0
# 95      0              0                              0                 0
# 96      0              0                              0                 0
#
#     Vietnamese Restaurant  Wine Bar  Wings Joint  Women's Store  Yoga Studio
# 92                      0         0            0              0            0
# 93                      0         0            0              0            0
# 94                      0         0            0              0            0
# 95                      0         0            0              0            0
# 96                      0         0            0              0            0
#
# [5 rows x 222 columns]

# %%
toronto_onehot.shape
# Out:
# (1793, 222)

# %%
toronto_grouped = toronto_onehot.groupby('Neighborhood').mean()
toronto_grouped.reset_index(inplace=True)
toronto_grouped.head()
# Out:
#                         Neighborhood  Adult Boutique  Afghan Restaurant  \
# 0           Adelaide, King, Richmond             0.0                0.0
# 1  Bedford Park, Lawrence Manor East             0.0                0.0
# 2                        Berczy Park             0.0                0.0
# 3        Cabbagetown, St. James Town             0.0                0.0
# 4                 Central Bay Street             0.0                0.0
#
#    American Restaurant  Antique Shop  Aquarium  Argentinian Restaurant  \
# 0             0.040000           0.0       0.0                     0.0
# 1             0.043478           0.0       0.0                     0.0
# 2             0.000000           0.0       0.0                     0.0
# 3             0.022727           0.0       0.0                     0.0
# 4             0.011364           0.0       0.0                     0.0
#
#    Art Gallery  Art Museum  Arts & Crafts Store  ...  Toy / Game Store  Trail  \
# 0     0.010000    0.010000                  0.0  ...               0.0    0.0
# 1     0.000000    0.000000                  0.0  ...               0.0    0.0
# 2     0.017544    0.000000                  0.0  ...               0.0    0.0
# 3     0.000000    0.000000                  0.0  ...               0.0    0.0
# 4     0.000000    0.011364                  0.0  ...               0.0    0.0
#
#    Train Station  Vegetarian / Vegan Restaurant  Video Game Store  \
# 0            0.0                       0.010000               0.0
# 1            0.0                       0.000000               0.0
# 2            0.0                       0.017544               0.0
# 3            0.0                       0.000000               0.0
# 4            0.0                       0.011364               0.0
#
#    Vietnamese Restaurant  Wine Bar  Wings Joint  Women's Store  Yoga Studio
# 0                    0.0  0.010000          0.0            0.0     0.000000
# 1                    0.0  0.000000          0.0            0.0     0.000000
# 2                    0.0  0.000000          0.0            0.0     0.000000
# 3                    0.0  0.000000          0.0            0.0     0.000000
# 4                    0.0  0.011364          0.0            0.0     0.011364
#
# [5 rows x 222 columns]

# %% [markdown]
# ### 5. Next, let's analyze the most frequent venues in each neighborhood

# %%
num_top_venues = 5

for hood in toronto_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = toronto_grouped[toronto_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Adelaide, King, Richmond----
#                  venue  freq
# 0          Coffee Shop  0.06
# 1                 Café  0.05
# 2  American Restaurant  0.04
# 3           Steakhouse  0.04
# 4      Thai Restaurant  0.04
#
#
# ----Bedford Park, Lawrence Manor East----
#                   venue  freq
# 0           Coffee Shop  0.09
# 1    Italian Restaurant  0.09
# 2  Fast Food Restaurant  0.09
# 3     Indian Restaurant  0.04
# 4       Thai Restaurant  0.04
#
#
# ----Berczy Park----
#           venue  freq
# 0   Coffee Shop  0.09
# 1  Cocktail Bar  0.05
# 2        Bakery  0.04
# 3    Restaurant  0.04
# 4      Beer Bar  0.04
#
#
# ----Cabbagetown, St. James Town----
#                 venue  freq
# 0         Coffee Shop  0.09
# 1  Italian Restaurant  0.05
# 2              Bakery  0.05
# 3                 Pub  0.05
# 4          Restaurant  0.05
#
#
# ----Central Bay Street----
#                 venue  freq
# 0         Coffee Shop  0.15
# 1                Café  0.06
# 2  Italian Restaurant  0.05
# 3        Burger Joint  0.03
# 4              Bakery  0.02
#
#
# ----Chinatown, Grange Park, Kensington Market----
#                            venue  freq
# 0                           Café  0.08
# 1  Vegetarian / Vegan Restaurant  0.06
# 2                            Bar  0.05
# 3             Mexican Restaurant  0.04
# 4                         Bakery  0.04
#
#
# ----Church and Wellesley----
#                  venue  freq
# 0          Coffee Shop  0.07
# 1  Japanese Restaurant  0.07
# 2              Gay Bar  0.06
# 3     Sushi Restaurant  0.05
# 4           Restaurant  0.03
#
#
# ----Commerce Court, Victoria Hotel----
#                  venue  freq
# 0          Coffee Shop  0.11
# 1                 Café  0.07
# 2                Hotel  0.06
# 3           Restaurant  0.05
# 4  American Restaurant  0.04
#
#
# ----Davisville----
#                 venue  freq
# 0      Sandwich Place  0.09
# 1         Pizza Place  0.09
# 2        Dessert Shop  0.09
# 3         Coffee Shop  0.06
# 4  Italian Restaurant  0.06
#
#
# ----Design Exchange, Toronto Dominion Centre----
#          venue  freq
# 0  Coffee Shop  0.12
# 1        Hotel  0.08
# 2         Café  0.08
# 3   Restaurant  0.05
# 4    Gastropub  0.03
#
#
# ----Dovercourt Village, Dufferin----
#          venue  freq
# 0       Bakery  0.10
# 1     Pharmacy  0.10
# 2  Supermarket  0.10
# 3          Gym  0.05
# 4  Music Venue  0.05
#
#
# ----Fairview, Henry Farm, Oriole----
#                   venue  freq
# 0        Clothing Store  0.11
# 1           Coffee Shop  0.08
# 2  Fast Food Restaurant  0.08
# 3   Japanese Restaurant  0.03
# 4      Toy / Game Store  0.03
#
#
# ----First Canadian Place, Underground city----
#          venue  freq
# 0  Coffee Shop  0.09
# 1         Café  0.09
# 2        Hotel  0.04
# 3    Gastropub  0.03
# 4          Bar  0.03
#
#
# ----Flemingdon Park, Don Mills South----
#                  venue  freq
# 0           Beer Store  0.10
# 1          Coffee Shop  0.10
# 2     Asian Restaurant  0.10
# 3                  Gym  0.10
# 4  Sporting Goods Shop  0.05
#
#
# ----Harbord, University of Toronto----
#                  venue  freq
# 0                 Café  0.15
# 1                  Bar  0.06
# 2  Japanese Restaurant  0.06
# 3            Bookstore  0.06
# 4               Bakery  0.06
#
#
# ----Harbourfront East, Toronto Islands, Union Station----
#                 venue  freq
# 0         Coffee Shop  0.12
# 1            Aquarium  0.05
# 2               Hotel  0.05
# 3  Italian Restaurant  0.04
# 4                Café  0.04
#
#
# ----Harbourfront, Regent Park----
#          venue  freq
# 0  Coffee Shop  0.15
# 1       Bakery  0.07
# 2          Pub  0.07
# 3         Café  0.07
# 4         Park  0.07
#
#
# ----High Park, The Junction South----
#                        venue  freq
# 0         Mexican Restaurant  0.09
# 1                        Bar  0.09
# 2                       Café  0.09
# 3  Cajun / Creole Restaurant  0.04
# 4                  Speakeasy  0.04
#
#
# ----Leaside----
#                     venue  freq
# 0             Coffee Shop  0.09
# 1     Sporting Goods Shop  0.09
# 2            Burger Joint  0.06
# 3  Furniture / Home Store  0.06
# 4              Sports Bar  0.03
#
#
# ----Little Portugal, Trinity–Bellwoods----
#                      venue  freq
# 0                      Bar  0.13
# 1              Coffee Shop  0.05
# 2         Asian Restaurant  0.05
# 3                     Café  0.03
# 4  New American Restaurant  0.03
#
#
# ----North Toronto West----
#                     venue  freq
# 0          Clothing Store  0.15
# 1             Coffee Shop  0.10
# 2             Yoga Studio  0.05
# 3  Furniture / Home Store  0.05
# 4                    Park  0.05
#
#
# ----Queen's Park----
#                  venue  freq
# 0          Coffee Shop  0.23
# 1                  Gym  0.05
# 2                Diner  0.05
# 3  Japanese Restaurant  0.05
# 4          Yoga Studio  0.03
#
#
# ----Runnymede, Swansea----
#               venue  freq
# 0              Café  0.10
# 1       Coffee Shop  0.08
# 2       Pizza Place  0.08
# 3  Sushi Restaurant  0.05
# 4               Gym  0.05
#
#
# ----Ryerson, Garden District----
#                        venue  freq
# 0                Coffee Shop  0.08
# 1             Clothing Store  0.07
# 2                       Café  0.04
# 3             Cosmetics Shop  0.04
# 4  Middle Eastern Restaurant  0.03
#
#
# ----St. James Town----
#             venue  freq
# 0     Coffee Shop  0.08
# 1            Café  0.05
# 2           Hotel  0.05
# 3      Restaurant  0.05
# 4  Cosmetics Shop  0.04
#
#
# ----Stn A PO Boxes 25 The Esplanade----
#           venue  freq
# 0   Coffee Shop  0.11
# 1          Café  0.04
# 2    Restaurant  0.04
# 3      Beer Bar  0.03
# 4  Cocktail Bar  0.03
#
#
# ----Studio District----
#                  venue  freq
# 0                 Café  0.11
# 1          Coffee Shop  0.08
# 2   Italian Restaurant  0.05
# 3               Bakery  0.05
# 4  American Restaurant  0.05
#
#
# ----The Annex, North Midtown, Yorkville----
#             venue  freq
# 0  Sandwich Place  0.12
# 1     Coffee Shop  0.12
# 2            Café  0.12
# 3     Pizza Place  0.08
# 4  Cosmetics Shop  0.04
#
#
# ----The Beaches West, India Bazaar----
#             venue  freq
# 0            Park  0.09
# 1  Sandwich Place  0.09
# 2    Burger Joint  0.05
# 3    Liquor Store  0.05
# 4       Pet Store  0.05
#
#
# ----The Danforth West, Riverdale----
#                     venue  freq
# 0        Greek Restaurant  0.18
# 1             Coffee Shop  0.09
# 2          Ice Cream Shop  0.07
# 3      Italian Restaurant  0.05
# 4  Furniture / Home Store  0.05
#
#
# ----Willowdale South----
#               venue  freq
# 0       Coffee Shop  0.09
# 1  Ramen Restaurant  0.09
# 2              Café  0.06
# 3    Sandwich Place  0.06
# 4  Sushi Restaurant  0.06

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#                         Neighborhood 1st Most Common Venue  \
# 0           Adelaide, King, Richmond           Coffee Shop
# 1  Bedford Park, Lawrence Manor East    Italian Restaurant
# 2                        Berczy Park           Coffee Shop
# 3        Cabbagetown, St. James Town           Coffee Shop
# 4                 Central Bay Street           Coffee Shop
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0                  Café   American Restaurant            Steakhouse
# 1           Coffee Shop  Fast Food Restaurant         Grocery Store
# 2          Cocktail Bar                Bakery    Seafood Restaurant
# 3           Pizza Place                Bakery                  Café
# 4                  Café    Italian Restaurant          Burger Joint
#
#      5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0          Thai Restaurant                 Hotel                Bakery
# 1  Comfort Food Restaurant              Pharmacy           Pizza Place
# 2                     Café            Restaurant              Beer Bar
# 3                      Pub                Market    Italian Restaurant
# 4                      Bar    Chinese Restaurant      Sushi Restaurant
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0          Burger Joint                   Gym                    Bar
# 1                   Pub            Restaurant         Sandwich Place
# 2            Steakhouse           Cheese Shop         Farmers Market
# 3            Restaurant             Gastropub            Flower Shop
# 4           Salad Place                   Spa    Japanese Restaurant

# %% [markdown]
# ### 6. Finally, let's run k-means algorithms to split the neighborhoods into 4 clusters.

# %%
# set number of clusters
kclusters = 4

toronto_grouped_clustering = toronto_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_
# Out:
# array([3, 2, 3, 3, 3, 0, 3, 3, 2, 3, 0, 1, 3, 1, 0, 3, 3, 0, 2, 0, 1, 2,
#        2, 3, 3, 3, 3, 2, 2, 2, 2], dtype=int32)

# %%
# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)
toronto_merged = df.loc[df['Neighborhood'].isin(toronto_venues['Neighborhood'].unique())]

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

toronto_merged.head()
# Out:
#    Postcode       Borough                      Neighborhood   Latitude  \
# 18      M2J    North York      Fairview, Henry Farm, Oriole  43.778517
# 22      M2N    North York                  Willowdale South  43.770120
# 27      M3C    North York  Flemingdon Park, Don Mills South  43.725900
# 38      M4G     East York                           Leaside  43.709060
# 41      M4K  East Toronto      The Danforth West, Riverdale  43.679557
#
#     Longitude  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 18 -79.346556               1        Clothing Store  Fast Food Restaurant
# 22 -79.408493               2           Coffee Shop      Ramen Restaurant
# 27 -79.340923               1           Coffee Shop                   Gym
# 38 -79.363452               2   Sporting Goods Shop           Coffee Shop
# 41 -79.352188               2      Greek Restaurant           Coffee Shop
#
#      3rd Most Common Venue   4th Most Common Venue 5th Most Common Venue  \
# 18             Coffee Shop        Toy / Game Store            Restaurant
# 22        Sushi Restaurant              Restaurant        Sandwich Place
# 27        Asian Restaurant              Beer Store         Grocery Store
# 38  Furniture / Home Store            Burger Joint             Pet Store
# 41          Ice Cream Shop  Furniture / Home Store             Bookstore
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 18             Juice Bar         Jewelry Store      Asian Restaurant
# 22                  Café         Movie Theater        Ice Cream Shop
# 27    Italian Restaurant             Bike Shop    Chinese Restaurant
# 38            Restaurant             Bike Shop         Smoothie Shop
# 41    Italian Restaurant           Pizza Place               Brewery
#
#    9th Most Common Venue 10th Most Common Venue
# 18              Tea Room            Bus Station
# 22         Grocery Store    Japanese Restaurant
# 27        Clothing Store         Discount Store
# 38        Breakfast Spot                Brewery
# 41       Bubble Tea Shop                   Café

# %% [markdown]
# ### 7. Now after all the work has be done, we can analyze the results.
#
#     7.a. We can visualize the clusters and examine the plots in case there is a clear visual pattern.

# %%
import matplotlib.cm as cm
import matplotlib.colors as colors
# create map
address = 'Toronto, Canada'

geolocator = Nominatim(user_agent="tor_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], 
                                  toronto_merged['Longitude'], 
                                  toronto_merged['Neighborhood'],
                                  toronto_merged['Cluster Labels']):
    cluster = int(cluster)
    label = folium.Popup(str(poi) + ' Cluster ' 
                         + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)

display(map_clusters)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# _Although, we can't say that the results are obvious, we can mention several observations_:
# - cluster 3 (yellow) clearly corresponds to the Downtown part of the Toronto,
# - cluster 0 (red) is close to cluster 3, but it seems to be located slightly to the left from the center of the city, so probably it corresponds to a less busy central part of Toronto,
# - clusters 1 and 2(blue and purple) both contain neighborhoods that a re located further from the city center, so most likely they correspond to the residential neighborhoods.

# %% [markdown]
#     7.b. To gain more information about the clusters, let's look at the summary for each of them.

# %% [markdown]
# __Cluster 0__:

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 0, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#              Borough  Cluster Labels 1st Most Common Venue  \
# 66  Downtown Toronto               0                  Café
# 67  Downtown Toronto               0                  Café
# 76      West Toronto               0              Pharmacy
# 77      West Toronto               0                   Bar
# 82      West Toronto               0    Mexican Restaurant
#
#             2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 66            Japanese Restaurant                   Bar                Bakery
# 67  Vegetarian / Vegan Restaurant                   Bar   Dumpling Restaurant
# 76                         Bakery           Supermarket                   Bar
# 77               Asian Restaurant           Coffee Shop            Restaurant
# 82                           Café                   Bar                  Park
#
#    5th Most Common Venue      6th Most Common Venue 7th Most Common Venue  \
# 66             Bookstore                 Restaurant    Italian Restaurant
# 67    Mexican Restaurant                     Bakery           Coffee Shop
# 76                   Gym               Liquor Store  Fast Food Restaurant
# 77                  Café                Pizza Place          Cocktail Bar
# 82                Bakery  Cajun / Creole Restaurant           Flea Market
#
#         8th Most Common Venue  9th Most Common Venue   10th Most Common Venue
# 66                   Beer Bar             Beer Store           Sandwich Place
# 67         Chinese Restaurant  Vietnamese Restaurant             Cocktail Bar
# 76  Middle Eastern Restaurant         Discount Store              Music Venue
# 77                     Bakery            Men's Store  New American Restaurant
# 82                  Speakeasy              Bookstore      Fried Chicken Joint

# %% [markdown]
# __Cluster 1__:

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 1, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#             Borough  Cluster Labels 1st Most Common Venue  \
# 18       North York               1        Clothing Store
# 27       North York               1           Coffee Shop
# 46  Central Toronto               1        Clothing Store
#
#    2nd Most Common Venue 3rd Most Common Venue   4th Most Common Venue  \
# 18  Fast Food Restaurant           Coffee Shop        Toy / Game Store
# 27                   Gym      Asian Restaurant              Beer Store
# 46           Coffee Shop           Yoga Studio  Furniture / Home Store
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 18            Restaurant             Juice Bar         Jewelry Store
# 27         Grocery Store    Italian Restaurant             Bike Shop
# 46                   Spa  Fast Food Restaurant   Sporting Goods Shop
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 18      Asian Restaurant              Tea Room            Bus Station
# 27    Chinese Restaurant        Clothing Store         Discount Store
# 46         Metro Station    Mexican Restaurant     Salon / Barbershop

# %% [markdown]
# __Cluster 2__:

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 2, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#             Borough  Cluster Labels 1st Most Common Venue  \
# 22       North York               2           Coffee Shop
# 38        East York               2   Sporting Goods Shop
# 41     East Toronto               2      Greek Restaurant
# 42     East Toronto               2                  Park
# 47  Central Toronto               2        Sandwich Place
# 62       North York               2    Italian Restaurant
# 65  Central Toronto               2           Coffee Shop
# 84     West Toronto               2                  Café
# 85     Queen's Park               2           Coffee Shop
#
#    2nd Most Common Venue   3rd Most Common Venue   4th Most Common Venue  \
# 22      Ramen Restaurant        Sushi Restaurant              Restaurant
# 38           Coffee Shop  Furniture / Home Store            Burger Joint
# 41           Coffee Shop          Ice Cream Shop  Furniture / Home Store
# 42        Sandwich Place               Pet Store                 Brewery
# 47          Dessert Shop             Pizza Place                    Café
# 62           Coffee Shop    Fast Food Restaurant           Grocery Store
# 65        Sandwich Place                    Café             Pizza Place
# 84           Coffee Shop             Pizza Place                     Gym
# 85   Japanese Restaurant                     Gym                   Diner
#
#       5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 22           Sandwich Place                  Café         Movie Theater
# 38                Pet Store            Restaurant             Bike Shop
# 41                Bookstore    Italian Restaurant           Pizza Place
# 42             Burger Joint         Burrito Place                   Pub
# 47         Sushi Restaurant    Italian Restaurant           Coffee Shop
# 62  Comfort Food Restaurant              Pharmacy           Pizza Place
# 65                 Pharmacy     Indian Restaurant                  Park
# 84       Italian Restaurant      Sushi Restaurant                 Diner
# 85                     Café         Smoothie Shop          Burger Joint
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 22        Ice Cream Shop         Grocery Store    Japanese Restaurant
# 38         Smoothie Shop        Breakfast Spot                Brewery
# 41               Brewery       Bubble Tea Shop                   Café
# 42           Coffee Shop           Pizza Place          Movie Theater
# 47        Farmers Market     Indian Restaurant     Seafood Restaurant
# 62                   Pub            Restaurant         Sandwich Place
# 65                   Pub          Burger Joint           Liquor Store
# 84                   Pub            Restaurant      Electronics Store
# 85         Burrito Place    Seafood Restaurant           Liquor Store

# %% [markdown]
# __Cluster 3__:

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 3, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#              Borough  Cluster Labels 1st Most Common Venue  \
# 43      East Toronto               3                  Café
# 51  Downtown Toronto               3           Coffee Shop
# 52  Downtown Toronto               3           Coffee Shop
# 53  Downtown Toronto               3           Coffee Shop
# 54  Downtown Toronto               3           Coffee Shop
# 55  Downtown Toronto               3           Coffee Shop
# 56  Downtown Toronto               3           Coffee Shop
# 57  Downtown Toronto               3           Coffee Shop
# 58  Downtown Toronto               3           Coffee Shop
# 59  Downtown Toronto               3           Coffee Shop
# 60  Downtown Toronto               3           Coffee Shop
# 61  Downtown Toronto               3           Coffee Shop
# 69  Downtown Toronto               3           Coffee Shop
# 70  Downtown Toronto               3           Coffee Shop
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 43           Coffee Shop                Bakery   American Restaurant
# 51           Pizza Place                Bakery                  Café
# 52   Japanese Restaurant               Gay Bar      Sushi Restaurant
# 53                  Café                   Pub                Bakery
# 54        Clothing Store                  Café        Cosmetics Shop
# 55                 Hotel            Restaurant                  Café
# 56          Cocktail Bar                Bakery    Seafood Restaurant
# 57                  Café    Italian Restaurant          Burger Joint
# 58                  Café   American Restaurant            Steakhouse
# 59                 Hotel              Aquarium                  Café
# 60                 Hotel                  Café            Restaurant
# 61                  Café                 Hotel            Restaurant
# 69                  Café            Restaurant              Beer Bar
# 70                  Café                 Hotel            Restaurant
#
#         5th Most Common Venue     6th Most Common Venue 7th Most Common Venue  \
# 43         Italian Restaurant               Yoga Studio               Brewery
# 51                        Pub                    Market    Italian Restaurant
# 52                 Restaurant  Mediterranean Restaurant  Fast Food Restaurant
# 53                       Park                   Theater    Mexican Restaurant
# 54  Middle Eastern Restaurant                Restaurant   Sporting Goods Shop
# 55             Cosmetics Shop            Breakfast Spot    Italian Restaurant
# 56                       Café                Restaurant              Beer Bar
# 57                        Bar        Chinese Restaurant      Sushi Restaurant
# 58            Thai Restaurant                     Hotel                Bakery
# 59         Italian Restaurant                    Bakery            Restaurant
# 60                  Gastropub        Seafood Restaurant   American Restaurant
# 61        American Restaurant        Seafood Restaurant            Steakhouse
# 69         Seafood Restaurant                     Hotel          Cocktail Bar
# 70               Burger Joint                Steakhouse                   Bar
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 43    Seafood Restaurant        Sandwich Place            Cheese Shop
# 51            Restaurant             Gastropub            Flower Shop
# 52       Bubble Tea Shop                   Pub                   Café
# 53        Breakfast Spot     Electronics Store            Event Space
# 54  Fast Food Restaurant    Italian Restaurant               Tea Room
# 55             Gastropub                Bakery                   Park
# 56            Steakhouse           Cheese Shop         Farmers Market
# 57           Salad Place                   Spa    Japanese Restaurant
# 58          Burger Joint                   Gym                    Bar
# 59               Brewery           Pizza Place         Scenic Lookout
# 60         Deli / Bodega            Steakhouse     Italian Restaurant
# 61    Italian Restaurant                Bakery              Gastropub
# 69   Japanese Restaurant    Italian Restaurant               Creperie
# 70    Seafood Restaurant             Gastropub                 Bakery

# %% [markdown]
# - Indeed, looking at most popular venues in cluster 0, we notice that there are places like Flea market, Discount Store, etc, so it does look less busy than cluster 3.
#
# - Looking more closely at the venues in clusters 1 and 2, we notice that there are more shops/stores and gyms in cluster 1, while cluster 2 has more parks and restaurants, so we can conclude that cluster 2 is more lively and "_recreational_" and cluster 1 is more "_convenient_".
